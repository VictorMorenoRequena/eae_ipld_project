# %% [markdown]
# # Project 1: Image Cropper
#
# In this project we will be using NumPy to transform an image into an array, extract some basic information from it like its shape and size, and then crop it with a custom size. We will also be using PIL to read the image and Matplotlib to display it.
#
# There will be a default image to start with but this program shoud be able to work with any image.
#
# ### Project Tasks:
#
# - `1.1.` Take the image array `img_arr` and get its shape and size.
#
# - `1.2.` Define the dimensions of the crop, make sure that min is smaller than max and also that min is larger than 0 and max is smaller than the size of the image for every dimension. If not, print a message explaining the error.
#
# - `1.3.` Crop the image into a new array and display it.
#
# - `1.4.` Save the cropped image as a new file, declaring a variable to chose the new file name.

# %%
# The library you have to use
import numpy as np

# Some extra libraries to deal with images and files
from PIL import Image
import matplotlib.pyplot as plt

# %%
img_path = "/Users/victormorenorequena/Downloads/EAE/Programming/eae_ipld_project-main/data/starry_night.png"

with Image.open(img_path) as img:
    img_arr = np.array(img)

plt.imshow(img_arr)

# %%
from PIL import Image

# Replace with the path to your image
image_path = '/Users/victormorenorequena/Downloads/EAE/Programming/eae_ipld_project-main/data/starry_night.png'

# Open the image
img = Image.open(image_path)

# Get the height and width of the image
max_height, max_width = img.size

print(f"Height: {max_height} pixels")
print(f"Width: {max_width} pixels")
# Out:
# Height: 395 pixels
# Width: 395 pixels

# %%
from PIL import Image

# Example crop dimensions, modify them to test your code
crop_min_h = 1
crop_max_h = 500
crop_min_w = 1
crop_max_w = 400

# Get the image size
image_path = '/Users/victormorenorequena/Downloads/EAE/Programming/eae_ipld_project-main/data/starry_night.png'  # Replace with the path to your image
img = Image.open(image_path)
img_size = img.size

# Constraint checks
if not (0 < crop_min_h < crop_max_h < img_size[1]):
    print("Error: Invalid crop height dimensions.")

if not (0 < crop_min_w < crop_max_w < img_size[0]):
    print("Error: Invalid crop width dimensions.")
# Out:
# Error: Invalid crop height dimensions.
# Error: Invalid crop width dimensions.

# %%
#1.3, display the cropped image
# Generate the crop array using NumPy array slicing
cropped_img_arr = img_arr[crop_min_h:crop_max_h, crop_min_w:crop_max_w, :]

# Display the cropped image (you can use Matplotlib for this)
plt.imshow(cropped_img_arr)
plt.title('Cropped Image')
plt.show()

# %%
# Ex 1.4: Saving the cropped image into a new file, set the filename of the new image

cropped_img = Image.fromarray(cropped_img_arr)

# Set the filename of the new image
output_file_name = '/Users/victormorenorequena/Downloads/EAE/Programming/eae_ipld_project-main/data/starry_night.png'  # Replace with your desired output file name

# Save the cropped image as a new file
cropped_img.save(output_file_name)

print(f"Cropped image saved as {output_file_name}")
# Out:
# Cropped image saved as /Users/victormorenorequena/Downloads/EAE/Programming/eae_ipld_project-main/data/starry_night.png
